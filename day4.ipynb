# %% [markdown]
# <a href="https://colab.research.google.com/github/ullasbannur/AIML-PROJECT/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv("https://talentcocomedia.s3.amazonaws.com/ml-assets/heart-disease.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df['sex'].unique()
# Out:
# array([1, 0])

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# LabelEncoder can be used transform non numerical labels to numerical labels.

# %%
sex_enc=LabelEncoder()

# %%
data=df.copy()
data_1=data.copy()
data_1['sex']=sex_enc.fit_transform(data_1['sex'])

# %%
data_1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# Here in dataset sex column is already encoded as numerical values.

# %%
data_2=pd.get_dummies(data,columns=['sex'])

# %%
data_2.head()
# Out:
#    age  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63   3       145   233    1        0      150      0      2.3      0   0
# 1   37   2       130   250    0        1      187      0      3.5      0   0
# 2   41   1       130   204    0        0      172      0      1.4      2   0
# 3   56   1       120   236    0        1      178      0      0.8      2   0
# 4   57   0       120   354    0        1      163      1      0.6      2   0
#
#    thal  target  sex_0  sex_1
# 0     1       1      0      1
# 1     2       1      0      1
# 2     2       1      1      0
# 3     2       1      0      1
# 4     2       1      1      0

# %%
data_2.corr()
# Out:
#                age        cp  trestbps      chol       fbs   restecg  \
# age       1.000000 -0.068653  0.279351  0.213678  0.121308 -0.116211
# cp       -0.068653  1.000000  0.047608 -0.076904  0.094444  0.044421
# trestbps  0.279351  0.047608  1.000000  0.123174  0.177531 -0.114103
# chol      0.213678 -0.076904  0.123174  1.000000  0.013294 -0.151040
# fbs       0.121308  0.094444  0.177531  0.013294  1.000000 -0.084189
# restecg  -0.116211  0.044421 -0.114103 -0.151040 -0.084189  1.000000
# thalach  -0.398522  0.295762 -0.046698 -0.009940 -0.008567  0.044123
# exang     0.096801 -0.394280  0.067616  0.067023  0.025665 -0.070733
# oldpeak   0.210013 -0.149230  0.193216  0.053952  0.005747 -0.058770
# slope    -0.168814  0.119717 -0.121475 -0.004038 -0.059894  0.093045
# ca        0.276326 -0.181053  0.101389  0.070511  0.137979 -0.072042
# thal      0.068001 -0.161736  0.062210  0.098803 -0.032019 -0.011981
# target   -0.225439  0.433798 -0.144931 -0.085239 -0.028046  0.137230
# ...

# %%
data_1.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
sns.heatmap(data_2.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data_1)

# %%
plt.scatter(data_1[['age']], data_1[['chol']])

# %%
sns.pairplot(data_1, hue='cp')

# %%
data['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64
